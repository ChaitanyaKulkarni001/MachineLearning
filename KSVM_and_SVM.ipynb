# %% [markdown]
# <a href="https://colab.research.google.com/github/ChaitanyaKulkarni001/MachineLearning/blob/main/KSVM_and_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2024-10-01 at 10.38.23_48a5e713.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# SVM tries the nearest to create a hyperplane with maximum margin,
# where as KNN tries nearest some neighbours

# %% [markdown]
# ## Mapping to a higher demensional space :
#
# ### It can be highly compute-intensive
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-10-02 at 14.00.17_a4efc2b9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-10-02 at 14.07.35_43bf5229.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2024-10-02 at 15.53.03_d2514d6d.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# radial basis function (RBF) kernel is a popular kernel function used in machine learning algorithms, especially in support vector machine classification. It's also known as the Gaussian kernel or the exponential kernel.

# %%
from sklearn.svm import SVC as svc
classifier  = svc(kernel="linear")
# classifier.fit(X_train,y_train)
